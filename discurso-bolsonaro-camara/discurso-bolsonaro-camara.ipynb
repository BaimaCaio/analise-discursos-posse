# %%
import nltk
from nltk import tokenize
from nltk import FreqDist
from wordcloud import WordCloud
import string
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image
from unidecode import unidecode

# %%
#nltk.download()

# %%
discurso = open('discurso-bolsonaro-camara.txt', mode='r', encoding='utf-8').read().lower()
discurso = unidecode(discurso.replace('\n', ' '))

# %%
# Removendo pontuação
discurso_sem_pontuacao = ''.join([palavra for palavra in discurso if palavra not in string.punctuation])

# %%
# Isolando cada palavra
separar_palavras = tokenize.word_tokenize(discurso_sem_pontuacao, language='portuguese')

# %%
# Removendo palavras que se removidas não alteram o sentido das frases
nltk.download('stopwords')
stopwords = nltk.corpus.stopwords.words('portuguese')
palavras_sem_stop = [palavra for palavra in separar_palavras if palavra not in stopwords]
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\caim_\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
freq = FreqDist(palavras_sem_stop)
freq = freq.most_common(30)
freq
# Out:
# [('brasil', 13),
#  ('nacional', 7),
#  ('senhoras', 7),
#  ('deus', 6),
#  ('presidente', 5),
#  ('senhores', 5),
#  ('chefes', 5),
#  ('brasileiros', 5),
#  ('povo', 5),
#  ('todos', 5),
#  ('estado', 4),
#  ('governo', 4),
#  ('republica', 4),
#  ('aqui', 4),
#  ('brasileiro', 4),
#  ('casa', 4),
#  ('missao', 4),
#  ('pais', 4),
#  ('trabalho', 4),
#  ('acima', 4),
#  ('politica', 4),
#  ('congresso', 3),
#  ('federativa', 3),
#  ('nacao', 3),
#  ('brasileira', 3),
#  ('nao', 3),
#  ('vida', 3),
#  ('desafios', 3),
#  ('vamos', 3),
#  ('valorizar', 3)]

# %%
# adicionando mais alguns filtros
stopwords.extend(['nacional', 'brasil', 'senhoras', 'senhores', '-', 
'todos', 'todas', 'governo', 'brasileiro', 'brasileira',
'brasileiros', 'brasileiras', 'pais', 'política', 'nao'])

# %%
palavras_sem_stop = [palavra for palavra in separar_palavras if palavra not in stopwords]
freq = FreqDist(palavras_sem_stop)
top30 = freq.most_common(30)

top30
# Out:
# [('deus', 6),
#  ('presidente', 5),
#  ('chefes', 5),
#  ('povo', 5),
#  ('estado', 4),
#  ('republica', 4),
#  ('aqui', 4),
#  ('casa', 4),
#  ('missao', 4),
#  ('trabalho', 4),
#  ('acima', 4),
#  ('politica', 4),
#  ('congresso', 3),
#  ('federativa', 3),
#  ('nacao', 3),
#  ('vida', 3),
#  ('desafios', 3),
#  ('vamos', 3),
#  ('valorizar', 3),
#  ('forma', 3),
#  ('ruas', 3),
#  ('liberdade', 3),
#  ('democracia', 3),
#  ('sociedade', 3),
#  ('defesa', 3),
#  ('soberania', 3),
#  ('confianca', 3),
#  ('serao', 3),
#  ('senador', 2),
#  ('20', 2)]

# %%
nuvem_de_palavras = WordCloud(stopwords=stopwords,
                              height=480,
                              width=480,
                              max_words=30)
nuvem_de_palavras.generate(discurso_sem_pontuacao)
nuvem_de_palavras.to_file('nuvem.png')
Image.open('nuvem.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=480x480>

# %%
top30 = dict(top30)
df = pd.DataFrame.from_dict(top30.items())
df = df.rename(columns={0:'Palavras', 1:'Repetições'})

plt.bar(df['Palavras'], df['Repetições'])
plt.xticks(rotation=79)
plt.show()

# %%
# Passarei uma lista de palavras específicas para ver a quantidade de vezes que foi citada:
analise_palavras = [
    'ambiente',
    'natureza', 
    'fome', 
    'amazonia',
    'educacao',
    'saude',
    'orcamento' 
]


freq = dict(freq)


for palavra in analise_palavras:
    try:
        if freq[palavra]:
            print(f'{palavra}: {freq[palavra]}')
    except:
        print(f'{palavra}: 0')
# Out:
# ambiente: 1
# natureza: 0
# fome: 0
# amazonia: 0
# educacao: 1
# saude: 2
# orcamento: 0

# %% [markdown]
# #### Daqui pra baixo tento fazer análise de palavras a partir do radical

# %%
analise_palavras = [
    'ambient',
    'natur', 
    'amazoni',
    'educa',
    'saud',
    'democra' 
]

contagem_com_radicais = {}
for palavra in analise_palavras:  
    if palavra in discurso_sem_pontuacao:
        contagem_com_radicais[palavra] = discurso_sem_pontuacao.count(palavra)
    else:
        contagem_com_radicais[palavra] = 0


df = pd.DataFrame(contagem_com_radicais.items(), columns=['radical', 'frequencia'])
df.sort_values(by=['frequencia'], ascending=False).style.hide(axis='index')
# Out:
# <style type="text/css">
# </style>
# <table id="T_0514d">
#   <thead>
#     <tr>
#       <th id="T_0514d_level0_col0" class="col_heading level0 col0" >radical</th>
#       <th id="T_0514d_level0_col1" class="col_heading level0 col1" >frequencia</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_0514d_row0_col0" class="data row0 col0" >democra</td>
#       <td id="T_0514d_row0_col1" class="data row0 col1" >4</td>
#     </tr>
#     <tr>
#       <td id="T_0514d_row1_col0" class="data row1 col0" >saud</td>
#       <td id="T_0514d_row1_col1" class="data row1 col1" >2</td>
#     </tr>
#     <tr>
#       <td id="T_0514d_row2_col0" class="data row2 col0" >ambient</td>
#       <td id="T_0514d_row2_col1" class="data row2 col1" >1</td>
#     </tr>
#     <tr>
#       <td id="T_0514d_row3_col0" class="data row3 col0" >educa</td>
#       <td id="T_0514d_row3_col1" class="data row3 col1" >1</td>
#     </tr>
#     <tr>
#       <td id="T_0514d_row4_col0" class="data row4 col0" >natur</td>
#       <td id="T_0514d_row4_col1" class="data row4 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_0514d_row5_col0" class="data row5 col0" >amazoni</td>
#       <td id="T_0514d_row5_col1" class="data row5 col1" >0</td>
#     </tr>
#   </tbody>
# </table>
